# %%
import pandas as pd

# %%
train = pd.read_csv("train_data.csv")

# %%
train.head()
# Out:
#         id                                         annotation  \
# 0  doc_001  Светлана из Казани дает частные уроки английск...
# 1  doc_002  Елене назначили социальное пособие на ребенка,...
# 2  doc_003  Самый надежный способ не оказаться в долгах — ...
# 3  doc_004  Друзья Александра то и дело хвастаются, что по...
# 4  doc_005  Вы взяли в микрофинансовой организации заем на...
#
#                                                 tags  \
# 0  ['Начать бизнес', 'Самозанятые', 'Свое дело', ...
# 1  ['Защитить права', 'Банки', 'Банковская карта'...
# 2  ['Кредиты', 'Долги', 'Просрочки', 'Ипотека', '...
# 3  ['Инвестиции', 'Ценные бумаги', 'Фондовая бирж...
# 4      ['Займы', 'Долги', 'Риски', 'Защитить права']
#
#                                                 text
# 0  ## Кто такой самозанятый?\n\nПо закону самозан...
# 1  Первым делом нужно попросить банк проверить ма...
# 2  ## Не переоценивайте свои финансовые возможнос...
# 3  Просто прийти на биржу и купить ценные бумаги ...
# ...

# %%
train.shape
# Out:
# (350, 4)

# %%
validate = pd.read_csv("questions.csv")

# %%
validate
# Out:
#      ID вопроса                                             Вопрос
# 0             1  Как просрочка по «беспроцентному» займу скажет...
# 1             2  Как действовать вкладчику при отзыве лицензии,...
# 2             3  Как действовать при оспаривании незаконной про...
# 3             4  Как изменился лимит социального вычета на спор...
# 4             5  Чем отличаются сроки обращения за наследством ...
# ..          ...                                                ...
# 495         496  В каких случаях банк обязан вернуть клиенту де...
# 496         497  В каких случаях банк вправе приостанавливать о...
# 497         498  Чем защита денег на банковских счетах отличает...
# 498         499  Что проверяют банки по бизнес-плану по сравнен...
# 499         500  Чем отличается банковское финансирование с гос...
#
# [500 rows x 2 columns]
